# %% [markdown]
# # Tokenization, Stemming, n-gram and skip-gram generation

# %% [markdown]
# In this exercise, we'll the emails in the <i>twenty newsgroups</i> dataset to perform simple tokenization, stemming n-gram and skip-gram generation. More information on the <i>Twenty Newsgroups</i> dataset can be found on the [UCI website](http://kdd.ics.uci.edu/databases/20newsgroups/20newsgroups.html).
#
# **Prerequisites:**
# * load and preprocess data set in `00_prepare_data_set/01_preprocess_newsgroups_data.ipynb`

# %% [markdown]
# ## Setup database connectivity

# %% [markdown]
# We'll reuse our module from the previous notebook (***`00_database_connectivity_setup.ipynb`***) to establish connectivity to the database

# %%
# %run '00_database_connectivity_setup.ipynb'
# %matplotlib inline
from IPython.display import display
from IPython.display import HTML
# Out:
# /Users/shajek/anaconda/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %% [markdown]
# Your connection object is ***`conn`***:
# 1. Queries: You can run your queries using ***```psql.read_sql("""<YOUR SQL>""", conn)```***.
# 2. Create/Delete/Updates: You can run these statements using ***```psql.execute("""<YOUR SQL>""", conn)```***, followed by a ***```conn.commit()```*** command to ensure your transaction is committed. Otherwise your changes will be rolledback if you terminate your kernel.
#
# If you created a new connection object (say to connect to a new cluster) as shown in the last section of `00_database_connectivity_setup.ipynb` notebook, use that connection object where needed.

# %% [markdown]
# ## Generate n-grams and skip-grams

# %% [markdown]
# Skip grams are a generalization of n-grams where we relax the constraint that the tokens should be adjacent to each other. For instance, let's consider the phrase `"insurgents killed in ongoing fighting"`, if we tokenize this phrase and were to extract <i>unigrams</i> from it, we'd get `['insurgents', 'killed', 'in', 'ongoing', 'fighting']`. If we were to extract <i>bigrams</i>, then we'd get `[('insurgents','killed'), ('killed','in'), ('in','ongoing'), ('ongoing', 'fighting')]`. If we were to generalize this to `k-skip-n-gram`, for instance say `2-skip-bigram` we'd get the following tokens:
#
# `[('insurgents', 'killed'),
#     ('insurgents', 'in'),
#     ('insurgents', 'ongoing'),
#     ('killed', 'in'),
#     ('killed', 'ongoing'),
#     ('killed', 'fighting'),
#     ('in', 'ongoing'),
#     ('in', 'fighting'),
#     ('ongoing', 'fighting')]`
#
# In many NLP tasks, skip-grams have achieved comparable accuracy to models trained on n-grams with far fewer training samples. For more information on skip-grams please refer to [A Closer Look at Skip-gram Modelling](http://homepages.inf.ed.ac.uk/ballison/pdf/lrec_skipgrams.pdf)

# %% [markdown]
# ### Define the UDF to generate k-skip-n-grams

# %%
sql = """
    drop function if exists YOUR_SCHEMA.generate_k_skip_n_grams(text[], int, int) cascade;
    create function YOUR_SCHEMA.generate_k_skip_n_grams(
        tokens text[],
        k int,
        n int
    )
    returns setof text[]
    as
    $$
        from itertools import combinations
        def is_valid_k_skip(lst, k):
            '''
                Validate if a given n-gram list (of token indices) contains valid k-skips.
                For instance, a 2-skip bigram, includes 0-skip bigrams, 1-skip bigrams 
                and 2-skip bigrams.
            '''
            idx_diff = [(next_item[0] - current_item[0]) for current_item, next_item in zip(lst, lst[1:])]
            valid_skips = set(range(1, k+2))
            validity_check = [1 if idx in valid_skips else 0 for idx in idx_diff]
            #check if every index is a valid skip
            return sum(validity_check) == len(validity_check)

        def generate_k_skip_n_gram(lst, k, n):
            '''
                Return all k-skip, n-grams as defined in 
                http://homepages.inf.ed.ac.uk/ballison/pdf/lrec_skipgrams.pdf
                ex: "Insurgents killed in ongoing fighting"
                Bi-grams = {insurgents killed, killed in, in ongoing,
                ongoing fighting}.
                2-skip-bi-grams = {insurgents killed, insurgents in,
                insurgents ongoing, killed in, killed ongoing, killed
                fighting, in ongoing, in fighting, ongoing fighting}
                Tri-grams = {insurgents killed in, killed in ongoing, in
                ongoing fighting}.
                2-skip-tri-grams = {insurgents killed in, insurgents killed
                ongoing, insurgents killed fighting, insurgents in ongoing,
                insurgents in fighting, insurgents ongoing fighting, killed
                in ongoing, killed in fighting, killed ongoing fighting, in
                ongoing fighting}.
            '''
            if n > len(lst) or k > len(lst):
                raise 'Invalid values for n:{0} or k:{1}'.format(n, k) 
            #Optimization for normal n-grams (0-skip-n-grams)
            if(k==0):
                return zip(*[lst[i:] for i in range(n)])
            else:
                n_grams = combinations(enumerate(lst), n)
                return [[tup[1] for tup in ngram] for ngram in filter(lambda ngram: is_valid_k_skip(ngram, k), n_grams)]
        return generate_k_skip_n_gram(tokens, k, n)
    $$language plpythonu;
"""
psql.execute(sql, conn)
conn.commit()

# %% [markdown]
# ### Invoke the UDF to generate bigrams and trigrams on a sample document

# %%
sql = """
    select
        YOUR_SCHEMA.generate_k_skip_n_grams(
            tokens,
            0, --no. of skips (k)
            2  --n-gram (n=2 => bigram, n=3 => trigram etc.) 
        ) as bigram
    from
    (
        select
            regexp_split_to_array(
                regexp_replace(
                    trim(both from
                        $$ Natural language processing (NLP) is a field of computer science, artificial intelligence, and computational 
                        linguistics concerned with the interactions between computers and human (natural) languages. 
                        As such, NLP is related to the area of human–computer interaction. Many challenges in NLP involve 
                        natural language understanding, that is, enabling computers to derive meaning from human or 
                        natural language input, and others involve natural language generation. $$
                    ),
                    E'[\\\n\\\r]+', ' ', 'g'
                ),
                E'\\\s+'
            ) as tokens
    )q;
"""
df = psql.read_sql(sql, conn)
HTML(df.to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>bigram</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>[Natural, language]</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>[language, processing]</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>[processing, (NLP)]</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>[(NLP), is]</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>[is, a]</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>[a, field]</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>[field, of]</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>[of, computer]</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>[computer, science,]</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>[science,, artificial]</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>[artificial, intelligence,]</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>[intelligence,, and]</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>[and, computational]</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>[computational, linguistics]</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>[linguistics, concerned]</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>[concerned, with]</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>[with, the]</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>[the, interactions]</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>[interactions, between]</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>[between, computers]</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>[computers, and]</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>[and, human]</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>[human, (natural)]</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>[(natural), languages.]</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>[languages., As]</td>
#     </tr>
#     <tr>
#       <th>25</th>
#       <td>[As, such,]</td>
#     </tr>
#     <tr>
#       <th>26</th>
#       <td>[such,, NLP]</td>
#     </tr>
#     <tr>
#       <th>27</th>
#       <td>[NLP, is]</td>
#     </tr>
#     <tr>
#       <th>28</th>
#       <td>[is, related]</td>
#     </tr>
#     <tr>
#       <th>29</th>
#       <td>[related, to]</td>
#     </tr>
#     <tr>
#       <th>30</th>
#       <td>[to, the]</td>
#     </tr>
#     <tr>
#       <th>31</th>
#       <td>[the, area]</td>
#     </tr>
#     <tr>
#       <th>32</th>
#       <td>[area, of]</td>
#     </tr>
#     <tr>
#       <th>33</th>
#       <td>[of, human–computer]</td>
#     </tr>
#     <tr>
#       <th>34</th>
#       <td>[human–computer, interaction.]</td>
#     </tr>
#     <tr>
#       <th>35</th>
#       <td>[interaction., Many]</td>
#     </tr>
#     <tr>
#       <th>36</th>
#       <td>[Many, challenges]</td>
#     </tr>
#     <tr>
#       <th>37</th>
#       <td>[challenges, in]</td>
#     </tr>
#     <tr>
#       <th>38</th>
#       <td>[in, NLP]</td>
#     </tr>
#     <tr>
#       <th>39</th>
#       <td>[NLP, involve]</td>
#     </tr>
#     <tr>
#       <th>40</th>
#       <td>[involve, natural]</td>
#     </tr>
#     <tr>
#       <th>41</th>
#       <td>[natural, language]</td>
#     </tr>
#     <tr>
#       <th>42</th>
#       <td>[language, understanding,]</td>
#     </tr>
#     <tr>
#       <th>43</th>
#       <td>[understanding,, that]</td>
#     </tr>
#     <tr>
#       <th>44</th>
#       <td>[that, is,]</td>
#     </tr>
#     <tr>
#       <th>45</th>
#       <td>[is,, enabling]</td>
#     </tr>
#     <tr>
#       <th>46</th>
#       <td>[enabling, computers]</td>
#     </tr>
#     <tr>
#       <th>47</th>
#       <td>[computers, to]</td>
#     </tr>
#     <tr>
#       <th>48</th>
#       <td>[to, derive]</td>
#     </tr>
#     <tr>
#       <th>49</th>
#       <td>[derive, meaning]</td>
#     </tr>
#     <tr>
#       <th>50</th>
#       <td>[meaning, from]</td>
#     </tr>
#     <tr>
#       <th>51</th>
#       <td>[from, human]</td>
#     </tr>
#     <tr>
#       <th>52</th>
#       <td>[human, or]</td>
#     </tr>
#     <tr>
#       <th>53</th>
#       <td>[or, natural]</td>
#     </tr>
#     <tr>
#       <th>54</th>
#       <td>[natural, language]</td>
#     </tr>
#     <tr>
#       <th>55</th>
#       <td>[language, input,]</td>
#     </tr>
#     <tr>
#       <th>56</th>
#       <td>[input,, and]</td>
#     </tr>
#     <tr>
#       <th>57</th>
#       <td>[and, others]</td>
#     </tr>
#     <tr>
#       <th>58</th>
#       <td>[others, involve]</td>
#     </tr>
#     <tr>
#       <th>59</th>
#       <td>[involve, natural]</td>
#     </tr>
#     <tr>
#       <th>60</th>
#       <td>[natural, language]</td>
#     </tr>
#     <tr>
#       <th>61</th>
#       <td>[language, generation.]</td>
#     </tr>
#   </tbody>
# </table>

# %%
sql = """
    select
        YOUR_SCHEMA.generate_k_skip_n_grams(
            tokens,
            0, --no. of skips (k)
            3  --n-gram (n=2 => bigram, n=3 => trigram etc.) 
        ) as bigram
    from
    (
        select
            regexp_split_to_array(
                regexp_replace(
                    trim(both from
                        $$ Natural language processing (NLP) is a field of computer science, artificial intelligence, and computational 
                        linguistics concerned with the interactions between computers and human (natural) languages. 
                        As such, NLP is related to the area of human–computer interaction. Many challenges in NLP involve 
                        natural language understanding, that is, enabling computers to derive meaning from human or 
                        natural language input, and others involve natural language generation. $$
                    ),
                    E'[\\\n\\\r]+', ' ', 'g'
                ),
                E'\\\s+'
            ) as tokens
    )q;
"""
df = psql.read_sql(sql, conn)
HTML(df.to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>bigram</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>[Natural, language, processing]</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>[language, processing, (NLP)]</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>[processing, (NLP), is]</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>[(NLP), is, a]</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>[is, a, field]</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>[a, field, of]</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>[field, of, computer]</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>[of, computer, science,]</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>[computer, science,, artificial]</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>[science,, artificial, intelligence,]</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>[artificial, intelligence,, and]</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>[intelligence,, and, computational]</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>[and, computational, linguistics]</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>[computational, linguistics, concerned]</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>[linguistics, concerned, with]</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>[concerned, with, the]</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>[with, the, interactions]</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>[the, interactions, between]</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>[interactions, between, computers]</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>[between, computers, and]</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>[computers, and, human]</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>[and, human, (natural)]</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>[human, (natural), languages.]</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>[(natural), languages., As]</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>[languages., As, such,]</td>
#     </tr>
#     <tr>
#       <th>25</th>
#       <td>[As, such,, NLP]</td>
#     </tr>
#     <tr>
#       <th>26</th>
#       <td>[such,, NLP, is]</td>
#     </tr>
#     <tr>
#       <th>27</th>
#       <td>[NLP, is, related]</td>
#     </tr>
#     <tr>
#       <th>28</th>
#       <td>[is, related, to]</td>
#     </tr>
#     <tr>
#       <th>29</th>
#       <td>[related, to, the]</td>
#     </tr>
#     <tr>
#       <th>30</th>
#       <td>[to, the, area]</td>
#     </tr>
#     <tr>
#       <th>31</th>
#       <td>[the, area, of]</td>
#     </tr>
#     <tr>
#       <th>32</th>
#       <td>[area, of, human–computer]</td>
#     </tr>
#     <tr>
#       <th>33</th>
#       <td>[of, human–computer, interaction.]</td>
#     </tr>
#     <tr>
#       <th>34</th>
#       <td>[human–computer, interaction., Many]</td>
#     </tr>
#     <tr>
#       <th>35</th>
#       <td>[interaction., Many, challenges]</td>
#     </tr>
#     <tr>
#       <th>36</th>
#       <td>[Many, challenges, in]</td>
#     </tr>
#     <tr>
#       <th>37</th>
#       <td>[challenges, in, NLP]</td>
#     </tr>
#     <tr>
#       <th>38</th>
#       <td>[in, NLP, involve]</td>
#     </tr>
#     <tr>
#       <th>39</th>
#       <td>[NLP, involve, natural]</td>
#     </tr>
#     <tr>
#       <th>40</th>
#       <td>[involve, natural, language]</td>
#     </tr>
#     <tr>
#       <th>41</th>
#       <td>[natural, language, understanding,]</td>
#     </tr>
#     <tr>
#       <th>42</th>
#       <td>[language, understanding,, that]</td>
#     </tr>
#     <tr>
#       <th>43</th>
#       <td>[understanding,, that, is,]</td>
#     </tr>
#     <tr>
#       <th>44</th>
#       <td>[that, is,, enabling]</td>
#     </tr>
#     <tr>
#       <th>45</th>
#       <td>[is,, enabling, computers]</td>
#     </tr>
#     <tr>
#       <th>46</th>
#       <td>[enabling, computers, to]</td>
#     </tr>
#     <tr>
#       <th>47</th>
#       <td>[computers, to, derive]</td>
#     </tr>
#     <tr>
#       <th>48</th>
#       <td>[to, derive, meaning]</td>
#     </tr>
#     <tr>
#       <th>49</th>
#       <td>[derive, meaning, from]</td>
#     </tr>
#     <tr>
#       <th>50</th>
#       <td>[meaning, from, human]</td>
#     </tr>
#     <tr>
#       <th>51</th>
#       <td>[from, human, or]</td>
#     </tr>
#     <tr>
#       <th>52</th>
#       <td>[human, or, natural]</td>
#     </tr>
#     <tr>
#       <th>53</th>
#       <td>[or, natural, language]</td>
#     </tr>
#     <tr>
#       <th>54</th>
#       <td>[natural, language, input,]</td>
#     </tr>
#     <tr>
#       <th>55</th>
#       <td>[language, input,, and]</td>
#     </tr>
#     <tr>
#       <th>56</th>
#       <td>[input,, and, others]</td>
#     </tr>
#     <tr>
#       <th>57</th>
#       <td>[and, others, involve]</td>
#     </tr>
#     <tr>
#       <th>58</th>
#       <td>[others, involve, natural]</td>
#     </tr>
#     <tr>
#       <th>59</th>
#       <td>[involve, natural, language]</td>
#     </tr>
#     <tr>
#       <th>60</th>
#       <td>[natural, language, generation.]</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Invoke the UDF to generate `2-skip-bi-grams`

# %%
sql = """
    select
        YOUR_SCHEMA.generate_k_skip_n_grams(
            tokens,
            2, --no. of skips (k)
            2  --n-gram (n=2 => bigram, n=3 => trigram etc.) 
        ) as bigram
    from
    (
        select
            regexp_split_to_array(
                regexp_replace(
                    trim(both from
                        $$ Natural language processing (NLP) is a field of computer science, artificial intelligence, and computational 
                        linguistics concerned with the interactions between computers and human (natural) languages. 
                        As such, NLP is related to the area of human–computer interaction. Many challenges in NLP involve 
                        natural language understanding, that is, enabling computers to derive meaning from human or 
                        natural language input, and others involve natural language generation. $$
                    ),
                    E'[\\\n\\\r]+', ' ', 'g'
                ),
                E'\\\s+'
            ) as tokens
    )q;
"""
df = psql.read_sql(sql, conn)
HTML(df.to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>bigram</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>[Natural, language]</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>[Natural, processing]</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>[Natural, (NLP)]</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>[language, processing]</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>[language, (NLP)]</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>[language, is]</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>[processing, (NLP)]</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>[processing, is]</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>[processing, a]</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>[(NLP), is]</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>[(NLP), a]</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>[(NLP), field]</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>[is, a]</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>[is, field]</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>[is, of]</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>[a, field]</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>[a, of]</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>[a, computer]</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>[field, of]</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>[field, computer]</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>[field, science,]</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>[of, computer]</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>[of, science,]</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>[of, artificial]</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>[computer, science,]</td>
#     </tr>
#     <tr>
#       <th>25</th>
#       <td>[computer, artificial]</td>
#     </tr>
#     <tr>
#       <th>26</th>
#       <td>[computer, intelligence,]</td>
#     </tr>
#     <tr>
#       <th>27</th>
#       <td>[science,, artificial]</td>
#     </tr>
#     <tr>
#       <th>28</th>
#       <td>[science,, intelligence,]</td>
#     </tr>
#     <tr>
#       <th>29</th>
#       <td>[science,, and]</td>
#     </tr>
#     <tr>
#       <th>30</th>
#       <td>[artificial, intelligence,]</td>
#     </tr>
#     <tr>
#       <th>31</th>
#       <td>[artificial, and]</td>
#     </tr>
#     <tr>
#       <th>32</th>
#       <td>[artificial, computational]</td>
#     </tr>
#     <tr>
#       <th>33</th>
#       <td>[intelligence,, and]</td>
#     </tr>
#     <tr>
#       <th>34</th>
#       <td>[intelligence,, computational]</td>
#     </tr>
#     <tr>
#       <th>35</th>
#       <td>[intelligence,, linguistics]</td>
#     </tr>
#     <tr>
#       <th>36</th>
#       <td>[and, computational]</td>
#     </tr>
#     <tr>
#       <th>37</th>
#       <td>[and, linguistics]</td>
#     </tr>
#     <tr>
#       <th>38</th>
#       <td>[and, concerned]</td>
#     </tr>
#     <tr>
#       <th>39</th>
#       <td>[computational, linguistics]</td>
#     </tr>
#     <tr>
#       <th>40</th>
#       <td>[computational, concerned]</td>
#     </tr>
#     <tr>
#       <th>41</th>
#       <td>[computational, with]</td>
#     </tr>
#     <tr>
#       <th>42</th>
#       <td>[linguistics, concerned]</td>
#     </tr>
#     <tr>
#       <th>43</th>
#       <td>[linguistics, with]</td>
#     </tr>
#     <tr>
#       <th>44</th>
#       <td>[linguistics, the]</td>
#     </tr>
#     <tr>
#       <th>45</th>
#       <td>[concerned, with]</td>
#     </tr>
#     <tr>
#       <th>46</th>
#       <td>[concerned, the]</td>
#     </tr>
#     <tr>
#       <th>47</th>
#       <td>[concerned, interactions]</td>
#     </tr>
#     <tr>
#       <th>48</th>
#       <td>[with, the]</td>
#     </tr>
#     <tr>
#       <th>49</th>
#       <td>[with, interactions]</td>
#     </tr>
#     <tr>
#       <th>50</th>
#       <td>[with, between]</td>
#     </tr>
#     <tr>
#       <th>51</th>
#       <td>[the, interactions]</td>
#     </tr>
#     <tr>
#       <th>52</th>
#       <td>[the, between]</td>
#     </tr>
#     <tr>
#       <th>53</th>
#       <td>[the, computers]</td>
#     </tr>
#     <tr>
#       <th>54</th>
#       <td>[interactions, between]</td>
#     </tr>
#     <tr>
#       <th>55</th>
#       <td>[interactions, computers]</td>
#     </tr>
#     <tr>
#       <th>56</th>
#       <td>[interactions, and]</td>
#     </tr>
#     <tr>
#       <th>57</th>
#       <td>[between, computers]</td>
#     </tr>
#     <tr>
#       <th>58</th>
#       <td>[between, and]</td>
#     </tr>
#     <tr>
#       <th>59</th>
#       <td>[between, human]</td>
#     </tr>
#     <tr>
#       <th>60</th>
#       <td>[computers, and]</td>
#     </tr>
#     <tr>
#       <th>61</th>
#       <td>[computers, human]</td>
#     </tr>
#     <tr>
#       <th>62</th>
#       <td>[computers, (natural)]</td>
#     </tr>
#     <tr>
#       <th>63</th>
#       <td>[and, human]</td>
#     </tr>
#     <tr>
#       <th>64</th>
#       <td>[and, (natural)]</td>
#     </tr>
#     <tr>
#       <th>65</th>
#       <td>[and, languages.]</td>
#     </tr>
#     <tr>
#       <th>66</th>
#       <td>[human, (natural)]</td>
#     </tr>
#     <tr>
#       <th>67</th>
#       <td>[human, languages.]</td>
#     </tr>
#     <tr>
#       <th>68</th>
#       <td>[human, As]</td>
#     </tr>
#     <tr>
#       <th>69</th>
#       <td>[(natural), languages.]</td>
#     </tr>
#     <tr>
#       <th>70</th>
#       <td>[(natural), As]</td>
#     </tr>
#     <tr>
#       <th>71</th>
#       <td>[(natural), such,]</td>
#     </tr>
#     <tr>
#       <th>72</th>
#       <td>[languages., As]</td>
#     </tr>
#     <tr>
#       <th>73</th>
#       <td>[languages., such,]</td>
#     </tr>
#     <tr>
#       <th>74</th>
#       <td>[languages., NLP]</td>
#     </tr>
#     <tr>
#       <th>75</th>
#       <td>[As, such,]</td>
#     </tr>
#     <tr>
#       <th>76</th>
#       <td>[As, NLP]</td>
#     </tr>
#     <tr>
#       <th>77</th>
#       <td>[As, is]</td>
#     </tr>
#     <tr>
#       <th>78</th>
#       <td>[such,, NLP]</td>
#     </tr>
#     <tr>
#       <th>79</th>
#       <td>[such,, is]</td>
#     </tr>
#     <tr>
#       <th>80</th>
#       <td>[such,, related]</td>
#     </tr>
#     <tr>
#       <th>81</th>
#       <td>[NLP, is]</td>
#     </tr>
#     <tr>
#       <th>82</th>
#       <td>[NLP, related]</td>
#     </tr>
#     <tr>
#       <th>83</th>
#       <td>[NLP, to]</td>
#     </tr>
#     <tr>
#       <th>84</th>
#       <td>[is, related]</td>
#     </tr>
#     <tr>
#       <th>85</th>
#       <td>[is, to]</td>
#     </tr>
#     <tr>
#       <th>86</th>
#       <td>[is, the]</td>
#     </tr>
#     <tr>
#       <th>87</th>
#       <td>[related, to]</td>
#     </tr>
#     <tr>
#       <th>88</th>
#       <td>[related, the]</td>
#     </tr>
#     <tr>
#       <th>89</th>
#       <td>[related, area]</td>
#     </tr>
#     <tr>
#       <th>90</th>
#       <td>[to, the]</td>
#     </tr>
#     <tr>
#       <th>91</th>
#       <td>[to, area]</td>
#     </tr>
#     <tr>
#       <th>92</th>
#       <td>[to, of]</td>
#     </tr>
#     <tr>
#       <th>93</th>
#       <td>[the, area]</td>
#     </tr>
#     <tr>
#       <th>94</th>
#       <td>[the, of]</td>
#     </tr>
#     <tr>
#       <th>95</th>
#       <td>[the, human–computer]</td>
#     </tr>
#     <tr>
#       <th>96</th>
#       <td>[area, of]</td>
#     </tr>
#     <tr>
#       <th>97</th>
#       <td>[area, human–computer]</td>
#     </tr>
#     <tr>
#       <th>98</th>
#       <td>[area, interaction.]</td>
#     </tr>
#     <tr>
#       <th>99</th>
#       <td>[of, human–computer]</td>
#     </tr>
#     <tr>
#       <th>100</th>
#       <td>[of, interaction.]</td>
#     </tr>
#     <tr>
#       <th>101</th>
#       <td>[of, Many]</td>
#     </tr>
#     <tr>
#       <th>102</th>
#       <td>[human–computer, interaction.]</td>
#     </tr>
#     <tr>
#       <th>103</th>
#       <td>[human–computer, Many]</td>
#     </tr>
#     <tr>
#       <th>104</th>
#       <td>[human–computer, challenges]</td>
#     </tr>
#     <tr>
#       <th>105</th>
#       <td>[interaction., Many]</td>
#     </tr>
#     <tr>
#       <th>106</th>
#       <td>[interaction., challenges]</td>
#     </tr>
#     <tr>
#       <th>107</th>
#       <td>[interaction., in]</td>
#     </tr>
#     <tr>
#       <th>108</th>
#       <td>[Many, challenges]</td>
#     </tr>
#     <tr>
#       <th>109</th>
#       <td>[Many, in]</td>
#     </tr>
#     <tr>
#       <th>110</th>
#       <td>[Many, NLP]</td>
#     </tr>
#     <tr>
#       <th>111</th>
#       <td>[challenges, in]</td>
#     </tr>
#     <tr>
#       <th>112</th>
#       <td>

# %% [markdown]
# ### Invoke the UDF to generate `2-skip-tri-grams`

# %%
sql = """
    select
        YOUR_SCHEMA.generate_k_skip_n_grams(
            tokens,
            2, --no. of skips (k)
            3  --n-gram (n=2 => bigram, n=3 => trigram etc.) 
        ) as bigram
    from
    (
        select
            regexp_split_to_array(
                regexp_replace(
                    trim(both from
                        $$ Natural language processing (NLP) is a field of computer science, artificial intelligence, and computational 
                        linguistics concerned with the interactions between computers and human (natural) languages. 
                        As such, NLP is related to the area of human–computer interaction. Many challenges in NLP involve 
                        natural language understanding, that is, enabling computers to derive meaning from human or 
                        natural language input, and others involve natural language generation. $$
                    ),
                    E'[\\\n\\\r]+', ' ', 'g'
                ),
                E'\\\s+'
            ) as tokens
    )q;
"""
df = psql.read_sql(sql, conn)
HTML(df.to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>bigram</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>[Natural, language, processing]</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>[Natural, language, (NLP)]</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>[Natural, language, is]</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>[Natural, processing, (NLP)]</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>[Natural, processing, is]</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>[Natural, processing, a]</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>[Natural, (NLP), is]</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>[Natural, (NLP), a]</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>[Natural, (NLP), field]</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>[language, processing, (NLP)]</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>[language, processing, is]</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>[language, processing, a]</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>[language, (NLP), is]</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>[language, (NLP), a]</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>[language, (NLP), field]</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>[language, is, a]</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>[language, is, field]</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>[language, is, of]</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>[processing, (NLP), is]</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>[processing, (NLP), a]</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>[processing, (NLP), field]</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>[processing, is, a]</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>[processing, is, field]</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>[processing, is, of]</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>[processing, a, field]</td>
#     </tr>
#     <tr>
#       <th>25</th>
#       <td>[processing, a, of]</td>
#     </tr>
#     <tr>
#       <th>26</th>
#       <td>[processing, a, computer]</td>
#     </tr>
#     <tr>
#       <th>27</th>
#       <td>[(NLP), is, a]</td>
#     </tr>
#     <tr>
#       <th>28</th>
#       <td>[(NLP), is, field]</td>
#     </tr>
#     <tr>
#       <th>29</th>
#       <td>[(NLP), is, of]</td>
#     </tr>
#     <tr>
#       <th>30</th>
#       <td>[(NLP), a, field]</td>
#     </tr>
#     <tr>
#       <th>31</th>
#       <td>[(NLP), a, of]</td>
#     </tr>
#     <tr>
#       <th>32</th>
#       <td>[(NLP), a, computer]</td>
#     </tr>
#     <tr>
#       <th>33</th>
#       <td>[(NLP), field, of]</td>
#     </tr>
#     <tr>
#       <th>34</th>
#       <td>[(NLP), field, computer]</td>
#     </tr>
#     <tr>
#       <th>35</th>
#       <td>[(NLP), field, science,]</td>
#     </tr>
#     <tr>
#       <th>36</th>
#       <td>[is, a, field]</td>
#     </tr>
#     <tr>
#       <th>37</th>
#       <td>[is, a, of]</td>
#     </tr>
#     <tr>
#       <th>38</th>
#       <td>[is, a, computer]</td>
#     </tr>
#     <tr>
#       <th>39</th>
#       <td>[is, field, of]</td>
#     </tr>
#     <tr>
#       <th>40</th>
#       <td>[is, field, computer]</td>
#     </tr>
#     <tr>
#       <th>41</th>
#       <td>[is, field, science,]</td>
#     </tr>
#     <tr>
#       <th>42</th>
#       <td>[is, of, computer]</td>
#     </tr>
#     <tr>
#       <th>43</th>
#       <td>[is, of, science,]</td>
#     </tr>
#     <tr>
#       <th>44</th>
#       <td>[is, of, artificial]</td>
#     </tr>
#     <tr>
#       <th>45</th>
#       <td>[a, field, of]</td>
#     </tr>
#     <tr>
#       <th>46</th>
#       <td>[a, field, computer]</td>
#     </tr>
#     <tr>
#       <th>47</th>
#       <td>[a, field, science,]</td>
#     </tr>
#     <tr>
#       <th>48</th>
#       <td>[a, of, computer]</td>
#     </tr>
#     <tr>
#       <th>49</th>
#       <td>[a, of, science,]</td>
#     </tr>
#     <tr>
#       <th>50</th>
#       <td>[a, of, artificial]</td>
#     </tr>
#     <tr>
#       <th>51</th>
#       <td>[a, computer, science,]</td>
#     </tr>
#     <tr>
#       <th>52</th>
#       <td>[a, computer, artificial]</td>
#     </tr>
#     <tr>
#       <th>53</th>
#       <td>[a, computer, intelligence,]</td>
#     </tr>
#     <tr>
#       <th>54</th>
#       <td>[field, of, computer]</td>
#     </tr>
#     <tr>
#       <th>55</th>
#       <td>[field, of, science,]</td>
#     </tr>
#     <tr>
#       <th>56</th>
#       <td>[field, of, artificial]</td>
#     </tr>
#     <tr>
#       <th>57</th>
#       <td>[field, computer, science,]</td>
#     </tr>
#     <tr>
#       <th>58</th>
#       <td>[field, computer, artificial]</td>
#     </tr>
#     <tr>
#       <th>59</th>
#       <td>[field, computer, intelligence,]</td>
#     </tr>
#     <tr>
#       <th>60</th>
#       <td>[field, science,, artificial]</td>
#     </tr>
#     <tr>
#       <th>61</th>
#       <td>[field, science,, intelligence,]</td>
#     </tr>
#     <tr>
#       <th>62</th>
#       <td>[field, science,, and]</td>
#     </tr>
#     <tr>
#       <th>63</th>
#       <td>[of, computer, science,]</td>
#     </tr>
#     <tr>
#       <th>64</th>
#       <td>[of, computer, artificial]</td>
#     </tr>
#     <tr>
#       <th>65</th>
#       <td>[of, computer, intelligence,]</td>
#     </tr>
#     <tr>
#       <th>66</th>
#       <td>[of, science,, artificial]</td>
#     </tr>
#     <tr>
#       <th>67</th>
#       <td>[of, science,, intelligence,]</td>
#     </tr>
#     <tr>
#       <th>68</th>
#       <td>[of, science,, and]</td>
#     </tr>
#     <tr>
#       <th>69</th>
#       <td>[of, artificial, intelligence,]</td>
#     </tr>
#     <tr>
#       <th>70</th>
#       <td>[of, artificial, and]</td>
#     </tr>
#     <tr>
#       <th>71</th>
#       <td>[of, artificial, computational]</td>
#     </tr>
#     <tr>
#       <th>72</th>
#       <td>[computer, science,, artificial]</td>
#     </tr>
#     <tr>
#       <th>73</th>
#       <td>[computer, science,, intelligence,]</td>
#     </tr>
#     <tr>
#       <th>74</th>
#       <td>[computer, science,, and]</td>
#     </tr>
#     <tr>
#       <th>75</th>
#       <td>[computer, artificial, intelligence,]</td>
#     </tr>
#     <tr>
#       <th>76</th>
#       <td>[computer, artificial, and]</td>
#     </tr>
#     <tr>
#       <th>77</th>
#       <td>[computer, artificial, computational]</td>
#     </tr>
#     <tr>
#       <th>78</th>
#       <td>[computer, intelligence,, and]</td>
#     </tr>
#     <tr>
#       <th>79</th>
#       <td>[computer, intelligence,, computational]</td>
#     </tr>
#     <tr>
#       <th>80</th>
#       <td>[computer, intelligence,, linguistics]</td>
#     </tr>
#     <tr>
#       <th>81</th>
#       <td>[science,, artificial, intelligence,]</td>
#     </tr>
#     <tr>
#       <th>82</th>
#       <td>[science,, artificial, and]</td>
#     </tr>
#     <tr>
#       <th>83</th>
#       <td>[science,, artificial, computational]</td>
#     </tr>
#     <tr>
#       <th>84</th>
#       <td>[science,, intelligence,, and]</td>
#     </tr>
#     <tr>
#       <th>85</th>
#       <td>[science,, intelligence,, computational]</td>
#     </tr>
#     <tr>
#       <th>86</th>
#       <td>[science,, intelligence,, linguistics]</td>
#     </tr>
#     <tr>
#       <th>87</th>
#       <td>[science,, and, computational]</td>
#     </tr>
#     <tr>
#       <th>88</th>
#       <td>[science,, and, linguistics]</td>
#     </tr>
#     <tr>
#       <th>89</th>
#       <td>[science,, and, concerned]</td>
#     </tr>
#     <tr>
#       <th>90</th>
#       <td>[artificial, intelligence,, and]</td>
#     </tr>
#     <tr>
#       <th>91</th>
#       <td>[artificial, intelligence,, computational]</td>
#     </tr>
#     <tr>
#       <th>92</th>
#       <td>[artificial, intelligence,, linguistics]</td>
#     </tr>
#     <tr>
#       <th>93</th>
#       <td>[artificial, and, computational]</td>
#     </tr>
#     <tr>
#       <th>94</th>
#       <td>[artificial, and, linguistics]</td>
#     </tr>
#     <tr>
#       <th>95</th>
#       <td>[artificial, and, concerned]</td>
#     </tr>
#     <tr>
#       <th>96</th>
#       <td>[artificial, computational, linguistics]</td>
#     </tr>
#     <tr>
#       <th>97</th>
#       <td>[artificial, computational, concerned]</td>
#     </tr>
#     <tr>
#       <th>98</th>
#       <td>[artificial, computational, with]</td>
#     </tr>
#     <tr>
#       <th>99</th>
#       <td>[intelligence,, and, computational]</td>
#     </tr>
#     <tr>
#       <th>10
